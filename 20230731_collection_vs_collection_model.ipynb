# %%
import weaviate
client = weaviate.Client("http://localhost:8089")

# %%
client.is_ready()
# Out:
# True

# %%
client.schema.delete_all()

# %%
client.schema.get()
# Out:
# {'classes': []}

# %% [markdown]
# ### Trying out collections

# %%
from weaviate import weaviate_classes as wvc

# %%
cat_collection_config = wvc.CollectionConfig(
    name="JeopardyCategory",
    description="A Jeopardy! category",
    properties=[
        wvc.Property(
            name="title",
            dataType=wvc.DataType.TEXT,
            tokenization=wvc.Tokenization.FIELD
        ),
    ],
    vectorizer=wvc.Vectorizer.TEXT2VEC_OPENAI,

    # QUESTION FOR DIRK - are invertedIndexConfig and vectorIndexConfig availble yet?
)

cat_collection = client.collection.create(cat_collection_config)

# %%
target_uuid = cat_collection.insert(
    {"title": "Famous people"}
)
print(target_uuid)
# Out:
# 01a8efa9-44d3-40e3-b222-78999cd98476

# %%
cat_collection.get()
# Out:
# [_Object(metadata=MetadataReturn(uuid=UUID('01a8efa9-44d3-40e3-b222-78999cd98476'), vector=None, creation_time_unix=1690881051350, last_update_time_unix=1690881051350, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None), data={'title': 'Famous people'})]

# %%
cat_collection.get(metadata=wvc.Metadata())
# Out:
# [_Object(metadata=MetadataReturn(uuid=UUID('01a8efa9-44d3-40e3-b222-78999cd98476'), vector=None, creation_time_unix=1690881051350, last_update_time_unix=1690881051350, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None), data={'title': 'Famous people'})]

# %%
wvc.Metadata??

# %%
cat_collection.get(metadata=wvc.Metadata(
    vector=True
))
# Out:
# [_Object(metadata=MetadataReturn(uuid=UUID('01a8efa9-44d3-40e3-b222-78999cd98476'), vector=[-0.01929024, 0.006585192, -0.0055663907, -0.021447701, -0.00010691463, 0.027553458, -0.01137955, 0.006934193, -0.006193888, -0.005862513, 0.03240422, 0.0077203265, 0.00087382464, 0.009038775, -0.00039615147, 0.0174007, 0.041710917, 0.02556521, 0.008199763, -0.03305287, 0.0011465919, 0.005717977, -0.005996473, -0.008354874, 0.015877787, 0.003058166, 0.011992946, -0.03294006, 0.00053848396, -0.018105753, 0.010949468, -0.010695649, 0.0065358384, -0.035732068, -0.018232662, 0.0025575785, 0.0012752641, -0.02972502, -0.001311398, 0.00482256, -0.008242066, 0.014481782, -0.01365687, -0.025875432, -0.0038601633, -0.012331371, 0.017245589, -0.049974132, -0.01632902, 0.030824903, 0.0374806, 0.00012668915, -0.009673323, -0.033673316, -0.006856637, 0.00091656845, -0.00012812129, -0.017950641, -0.0060846047, -0.008721502, 0.00856639, 0.0072479416, -0.015003521, 0.018965917, -0.026820203, -0.020009395, -0.006239716, 0.0076357205, -8.7690925e-05, 0.004071679, 0.026650991, 0.006839011, -0.0066345455, -0.022265563, 0.0033172728, 0.011344298, -0.00896827, 0.00073589874, 0.006063453, -0.005245592, 0.035139825, -0.019487657, -0.015327845, -0.014305519, 0.027398346, -0.016484132, -0.05609399, 0.009179786, -0.014171558, 0.010878962, 0.014495883, 0.028258512, 0.0017829019, -0.0019900112, -0.015229138, 0.022857808, -0.017992944, -0.0010707987, 0.026326668, -0.03198119, -0.0017388362, 0.0041703866, -0.017301993, -0.023224436, 0.0017423615, -0.020982368, 0.008150409, 0.023407748, 0.009525262, 0.026524082, -0.019628666, 0.025607513, -0.0013995295, -0.028188005, -0.013170384, -0.011175085, 0.021475904, 0.02450763, -0.0052773193, -0.02354876, 0.017245589, 0.01085076, 0.008954169, 0.0065534646, 0.013699173, 0.00042942114, -0.027102225, -0.02770857, 0.012634544, -0.0021363096, 0.026763799, -0.013875437, 0.047153924, -0.013071677, 0.0025540532, 0.05674264, -0.005964746, 0.0028889533, -0.008467683, -0.014495883, 0.015440653, 0.0374524, -0.015638068, -0.0026739123, -0.030796701, 0.018514683, 0.010462982, 0.0174148, -0.0062714433, 0.019981192, 0.016314918, 0.013177434, 0.034293763, 0.0049318434, 0.009616919, 0.00937015, -0.0037297287, 0.01123854, -0.012267916, -0.034209155, -0.00042853982, 0.015243239, 0.0014770854, -0.0020376022, 0.012817858, 0.045969434, 0.016413625, 0.017203284, -0.003962396, -0.007967095, 0.011534662, 0.010336072, -0.023619264, 0.011866037, 0.008347823, 0.017739125, 0.011273792, 0.012119856, -0.025607513, -0.0005569916, -0.014947116, 0.029753223, 0.012077552, 0.022815505, -0.0049318434, -0.007374851, 0.013036424, -0.024465328, -0.007240891, -0.030091649, -0.00060987053, 0.049804922, -0.004244417, 0.012430078, -0.63082474, -0.030458275, 0.005654522, 0.00883431, 0.010498234, 0.009144533, 0.0005102819, 0.036324315, -0.016145706, 0.023125727, 0.004886015, 0.0024958865, 0.013381899, -0.0074242046, -0.015074026, -0.015074026, 0.018895412, -0.029640414, -0.009574615, 0.011985895, 0.015285542, 0.02690481, -0.010526436, -0.005139834, 0.02113748, 0.01056874, 0.0240846, -0.027215034, 0.016498232, 0.022660393, -0.0033507629, 0.020954166, 0.0038072844, -0.024775552, 0.07563805, 0.0041950634, -0.0050129243, 0.04094946, 0.033419497, 0.04131609, -0.0348296, -0.024423024, 0.00036949167, 0.01017391, -0.010406577, 0.024549933, 0.0026809627, 0.008876613, -0.025579311, -0.0026545234, 0.03666274, 0.010780255, -0.0034159801, 0.0032132776, -0.023999993, 0.0028008218, 0.0040505277, -0.01634312, 0.0099341925, 0.012282018, -0.0013669209, 0.013854285, -0.0010196824, -0.004646297, 0.0042479425, 0.027088124, -0.019783778, 0.014164508, 0.020136304, -0.010491184, 0.0048789643, -0.0019177432, -0.032235008, 0.014524085, 0.01057579, 0.02745475, 0.032206807, -0.010124557, -0.043967083, 0.0018243238, 0.009144533, -0.0004970621, -0.009687424, -0.009313745, 0.011344298, 0.019741476, -0.023506457, 0.013804931, 0.024126902, 0.00052614557, 0.025438301, 0.02101057, 0.0033172728, -0.007614569,  ...

# %% [markdown]
# Should we just have vector=True here ⬆️? Not sure what other flags would be used.

# %%
question_collection_config = wvc.CollectionConfig(
    name="JeopardyQuestion",
    properties=[
        wvc.Property(name="question", dataType=wvc.DataType.TEXT),
        wvc.Property(name="answer", dataType=wvc.DataType.TEXT),
        wvc.ReferenceProperty(name="hasCategory", reference_class_name="JeopardyCategory")
    ],
    vectorizer=wvc.Vectorizer.TEXT2VEC_OPENAI)
question_collection = client.collection.create(question_collection_config)

# %%
from weaviate.util import generate_uuid5
question_collection.insert(
    {
        "question": "This person wrote 'Hey Jude'",
        "answer": "Paul McCartney",
        "hasCategory": wvc.RefToObject(target_uuid)
    },
    uuid = generate_uuid5("This person wrote 'Hey Jude'")
)
# Out:
# UUID('7b70183d-b099-5274-a489-cb33f60b2d45')

# %%
from_uuid = question_collection.insert(
    {
        "question": "This person sang 'Wrecking Ball'",
        "answer": "Miley Cyrus",
    },
    uuid = generate_uuid5("This person sang 'Wrecking Ball'")
)

# %%
print(from_uuid)
# Out:
# 85cc3555-4d60-5b48-84bd-6f0a3547e199

# %%
cref_resp = question_collection.reference_add(
    from_uuid=from_uuid,
    from_property="hasCategory",
    to_uuids=target_uuid
)
print(cref_resp)
# Out:
# None

# %%
objs = question_collection.get()

# %%
objs
# Out:
# [_Object(metadata=MetadataReturn(uuid=UUID('7b70183d-b099-5274-a489-cb33f60b2d45'), vector=None, creation_time_unix=1690881059544, last_update_time_unix=1690881059544, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None), data={'answer': 'Paul McCartney', 'hasCategory': [{'beacon': 'weaviate://localhost/01a8efa9-44d3-40e3-b222-78999cd98476', 'href': '/v1/objects/01a8efa9-44d3-40e3-b222-78999cd98476'}], 'question': "This person wrote 'Hey Jude'"}),
#  _Object(metadata=MetadataReturn(uuid=UUID('85cc3555-4d60-5b48-84bd-6f0a3547e199'), vector=None, creation_time_unix=1690881060721, last_update_time_unix=1690881061500, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None), data={'answer': 'Miley Cyrus', 'hasCategory': [{'beacon': 'weaviate://localhost/Jeopardycategory/01a8efa9-44d3-40e3-b222-78999cd98476', 'href': '/v1/objects/Jeopardycategory/01a8efa9-44d3-40e3-b222-78999cd98476'}], 'question': "This person sang 'Wrecking Ball'"})]

# %%
objs[0].data
# Out:
# {'answer': 'Paul McCartney',
#  'hasCategory': [{'beacon': 'weaviate://localhost/01a8efa9-44d3-40e3-b222-78999cd98476',
#    'href': '/v1/objects/01a8efa9-44d3-40e3-b222-78999cd98476'}],
#  'question': "This person wrote 'Hey Jude'"}

# %%
objs[0].data.keys()
# Out:
# dict_keys(['answer', 'hasCategory', 'question'])

# %%
objs[0].metadata
# Out:
# MetadataReturn(uuid=UUID('7b70183d-b099-5274-a489-cb33f60b2d45'), vector=None, creation_time_unix=1690881059544, last_update_time_unix=1690881059544, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None)

# %%
objs[0].metadata.uuid
# Out:
# UUID('7b70183d-b099-5274-a489-cb33f60b2d45')

# %%
objs[0].metadata.creation_time_unix
# Out:
# 1690881059544

# %%
cat_collection.get_grpc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cat_collection.get_grpc()
#
# TypeError: 'ReturnValues' object is not callable

# %% [markdown]
# ### Trying out collections w/ typed obj

# %%
client.schema.delete_class("Group")

# %%
from weaviate.collection.collection_model import (
    CollectionConfigModel,
    BaseProperty,
    PropertyConfig,
    ReferenceTo,
)

class Group(BaseProperty):
    name: str

collection = client.collection_model.create(
    CollectionConfigModel(vectorizer=wvc.Vectorizer.NONE), Group
)

# %%
collection.insert(obj=Group(name="Name"))
# Out:
# UUID('06ab4626-1805-4417-a783-653a35a1b033')

# %%
client.schema.delete_class("Jeopardyquestion")
client.schema.delete_class("Jeopardycategory")

# %% [markdown]
# Note: This handles CamelCase class names differently than standard (my bad, but still)
#
# `class JeopardyQuestion` did not delete the class created above (`Jeopardyquestion`)

# %%
from typing import Annotated
from weaviate.weaviate_types import UUIDS

from weaviate.collection.collection_model import (
    CollectionConfigModel,
    BaseProperty,
    PropertyConfig,
    ReferenceTo,
)

class JeopardyCategory(BaseProperty):
    title: Annotated[str, PropertyConfig(tokenization=wvc.Tokenization.FIELD)]

class JeopardyQuestion(BaseProperty):
    question: str
    answer: str
    hasCategory: Annotated[UUIDS, ReferenceTo(JeopardyCategory)]

cat_collection = client.collection_model.create(
    CollectionConfigModel(
        vectorizer=wvc.Vectorizer.NONE,
    ), JeopardyCategory
)

question_collection = client.collection_model.create(
    CollectionConfigModel(
        vectorizer=wvc.Vectorizer.NONE,
    ), JeopardyQuestion
)

# %% [markdown]
# Initial thoughts:
#
# Having models of objects are nice, which will be nice at object creation time. But, as a whole this feels quite complicated. (I guess this is firmly in the land of ORM?)
#
# For me, this involves more abstractions that I need to hold in my head vs the above model.

# %% [markdown]
# More specifically - this syntax lets me kind of think linearly from start to finish.
#
# - Oh, I need to define a collection
# - Run through mental list of parameters
#     - Start to define them one by one
#     - Define details of each property, etc.
#
# ```python
# import weaviate.weaviate_classes as wvc
#
# cat_collection_config = wvc.CollectionConfig(
#     name="JeopardyCategory",
#     properties=[
#         wvc.Property(
#             name="title",
#             dataType=wvc.DataType.TEXT,
#             tokenization=wvc.Tokenization.FIELD
#         ),
#     ],
#     vectorizer=None
# )
# ```
#
# Here, I think the cognitive load on my brain is higher. I have to know to:
# - define my class as a subclass of BaseProperty,
# - remember to use Annotated, and
# - split indexing options - property level options are in the class definition, and collection-level ones in the CollecitonConfigModel
#
# All of it makes sense, but it feels more difficult because there's more abstraction involved.
#
# ```python
# from typing import Annotated
# from weaviate.weaviate_types import UUIDS
#
# from weaviate.collection.collection_model import (
#     CollectionConfigModel,
#     BaseProperty,
#     PropertyConfig,
#     ReferenceTo,
# )
#
# class JeopardyCategory(BaseProperty):
#     title: Annotated[str, PropertyConfig(tokenization=wvc.Tokenization.FIELD)]
#
# cat_collection = client.collection_model.create(
#     CollectionConfigModel(
#         vectorizer=wvc.Vectorizer.NONE,
#     ), JeopardyCategory
# )
# ```

# %%
client.schema.create_class({"class": "JeopardyQuestion"})
# Out:
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeException             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 client.schema.create_class({"class": "JeopardyQuestion"})
#
# File ~/code/sandpit/try_new_wv_api_202306/.venv/lib/python3.10/site-packages/weaviate/schema/crud_schema.py:202, in Schema.create_class(self, schema_class)
#     200 # validate the class before loading
#     201 check_class(loaded_schema_class)
# --> 202 self._create_class_with_primitives(loaded_schema_class)
#     203 self._create_complex_properties_from_class(loaded_schema_class)
#
# File ~/code/sandpit/try_new_wv_api_202306/.venv/lib/python3.10/site-packages/weaviate/schema/crud_schema.py:767, in Schema._create_class_with_primitives(self, weaviate_class)
#     765     raise RequestsConnectionError("Class may not have been created properly.") from conn_err
#     766 if response.status_code != 200:
# --> 767     raise UnexpectedStatusCodeException("Create class", response)
#
# UnexpectedStatusCodeException: Create class! Unexpected status code: 422, with response body: {'error': [{'message': 'class name "JeopardyQuestion" already exists as a permutation of: "Jeopardyquestion". class names must be unique when lowercased'}]}.

# %%
client.schema.delete_class("JeopardyQuestion")
client.schema.delete_class("JeopardyCategory")

# %%
client.schema.get("Jeopardyquestion")
# Out:
# {'class': 'Jeopardyquestion',
#  'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#   'cleanupIntervalSeconds': 60,
#   'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#  'multiTenancyConfig': {'enabled': False},
#  'properties': [{'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'name': 'answer',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'name': 'question',
#    'tokenization': 'word'},
#   {'dataType': ['Jeopardycategory'],
#    'indexFilterable': True,
#    'indexSearchable': False,
#    'name': 'hascategory'}],
#  'replicationConfig': {'factor': 1},
#  'shardingConfig': {'virtualPerPhysical': 128,
#   'desiredCount': 1,
#   'actualCount': 1,
#   'desiredVirtualCount': 128,
#   'actualVirtualCount': 128,
#   'key': '_id',
#   'strategy': 'hash',
#   'function': 'murmur3'},
#  'vectorIndexConfig': {'skip': False,
#   'cleanupIntervalSeconds': 300,
#   'maxConnections': 64,
#   'efConstruction': 128,
#   'ef': -1,
#   'dynamicEfMin': 100,
#   'dynamicEfMax': 500,
#   'dynamicEfFactor': 8,
#   'vectorCacheMaxObjects': 1000000000000,
#   'flatSearchCutoff': 40000,
#   'distance': 'cosine',
#   'pq': {'enabled': False,
#    'bitCompression': False,
#    'segments': 0,
#    'centroids': 256,
#    'trainingLimit': 100000,
#    'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#  'vectorIndexType': 'hnsw',
#  'vectorizer': 'none'}

# %%
question_collection_config = wvc.CollectionConfig(
    name="JeopardyQuestion",
    properties=[
        wvc.Property(name="question", dataType=wvc.DataType.TEXT),
        wvc.Property(name="answer", dataType=wvc.DataType.TEXT),
        wvc.ReferenceProperty(name="hasCategory", reference_class_name="JeopardyCategory")
    ],
    vectorizer=wvc.Vectorizer.TEXT2VEC_OPENAI)
question_collection = client.collection.create(question_collection_config)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeException             Traceback (most recent call last)
# Cell In[36], line 9
#       1 question_collection_config = wvc.CollectionConfig(
#       2     name="JeopardyQuestion",
#       3     properties=[
#    (...)
#       7     ],
#       8     vectorizer=wvc.Vectorizer.TEXT2VEC_OPENAI)
# ----> 9 question_collection = client.collection.create(question_collection_config)
#
# File ~/code/sandpit/try_new_wv_api_202306/.venv/lib/python3.10/site-packages/weaviate/collection/collection.py:186, in Collection.create(self, config)
#     185 def create(self, config: CollectionConfig) -> CollectionObject:
# --> 186     name = super()._create(config)
#     188     return CollectionObject(self._connection, name)
#
# File ~/code/sandpit/try_new_wv_api_202306/.venv/lib/python3.10/site-packages/weaviate/collection/collection_base.py:262, in CollectionBase._create(self, model, properties, name)
#     260     raise RequestsConnectionError("Class may not have been created properly.") from conn_err
#     261 if response.status_code != 200:
# --> 262     raise UnexpectedStatusCodeException("Create class", response)
#     264 collection_name = response.json()["class"]
#     265 assert isinstance(collection_name, str)
#
# UnexpectedStatusCodeException: Create class! Unexpected status code: 422, with response body: {'error': [{'message': 'class name "Jeopardyquestion" already exists'}]}.

# %%
question_collection.get_grpc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 question_collection.get_grpc()
#
# TypeError: 'ReturnValues' object is not callable
